# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Aparna V
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I like playing with data inorder to discover insights and patterns from it._

# %% [markdown]
# ### The following code performs floor division between the provided numbers.

# %%
a=26
b=3
print (a//b)
# Out:
# 8

# %% [markdown]
# + one
# + two
# + three
# + four

# %% [markdown]
# a|b|result
# ---|---|---
# 26|3|8
# 54|6|9
# 66|3|22

# %% [markdown]
# ---

# %% [markdown]
# Here is a link to [Google’s](https://www.google.com “Google’s Homepage”) home page.
